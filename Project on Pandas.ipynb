# %% [markdown]
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>9/25/21, 4:29 PM</p>
# </blockquote></td>
# <td><blockquote>
# <p>Copy of pandas_basics_practice.ipynb - Colaboratory</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > **Consider the following Python dictionary data and Python list
# > labels:**
# >
# > data = {'birds': \['Cranes', 'Cranes', 'plovers', 'spoonbills',
# > 'spoonbills', 'Cranes', 'plovers', 'Cranes',
# >
# > 'spoonbills', 'spoonbills'\], 'age': \[3.5, 4, 1.5, np.nan, 6, 3, 5.5,
# > np.nan, 8, 4\], 'visits': \[2, 4, 3, 4, 3, 4, 2, 2,
# >
# > 3, 2\], 'priority': \['yes', 'yes', 'no', 'yes', 'no', 'no', 'no',
# > 'yes', 'no', 'no'\]}
# >
# > labels = \['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'\]
# >
# > **1. Create a DataFrame birds from this dictionary data which has the
# > index labels.**
# >
# > import pandas as pd
# > import numpy as np
# >
# > df = pd.DataFrame({'birds': \['Cranes', 'Cranes', 'plovers',
# > 'spoonbills', 'spoonbills', 'C df
#
# <table>
# <thead>
# <tr class="header">
# <th><strong>a</strong></th>
# <th><strong>birds</strong></th>
# <th><strong>age</strong></th>
# <th><strong>visits</strong></th>
# <th><blockquote>
# <p><strong>priority</strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td>Cranes</td>
# <td>3.5</td>
# <td>2</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>b</strong></td>
# <td>Cranes</td>
# <td>4.0</td>
# <td>4</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>c</strong></td>
# <td>plovers</td>
# <td>1.5</td>
# <td>3</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>d</strong></td>
# <td>spoonbills</td>
# <td>NaN</td>
# <td>4</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>e</strong></td>
# <td>spoonbills</td>
# <td>6.0</td>
# <td>3</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>f</strong></td>
# <td>Cranes</td>
# <td>3.0</td>
# <td>4</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>g</strong></td>
# <td>plovers</td>
# <td>5.5</td>
# <td>2</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>h</strong></td>
# <td>Cranes</td>
# <td>NaN</td>
# <td>2</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>i</strong></td>
# <td>spoonbills</td>
# <td>8.0</td>
# <td>3</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>j</strong></td>
# <td>spoonbills</td>
# <td>4.0</td>
# <td>2</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > **2. Display a summary of the basic information about birds DataFrame
# > and its data.**
# >
# > df.describe()
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>https://colab.research.google.com/drive/1yYBRi21r6oY0sB0G1zUdsnpVGary0Azw?authuser=2#printMode=true</p>
# </blockquote></td>
# <td>1/7</td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>9/25/21, 4:29 PM</p>
# </blockquote></th>
# <th>Copy of pandas_basics_practice.ipynb - Colaboratory</th>
# <th></th>
# <th></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><strong>age</strong></td>
# <td><blockquote>
# <p><strong>visits</strong></p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><strong>count</strong></td>
# <td>8.000000</td>
# <td><blockquote>
# <p>10.000000</p>
# </blockquote></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><strong>mean</strong></td>
# <td>4.437500</td>
# <td><blockquote>
# <p>2.900000</p>
# </blockquote></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p><strong>std</strong> 2.007797 0.875595<br />
# *<em>3. Print the �rst 2 rows of the birds dataframe *</em></p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><strong>min</strong></td>
# <td><blockquote>
# <p>1.500000</p>
# </blockquote></td>
# <td><blockquote>
# <p>2.000000</p>
# </blockquote></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td>df.head(2)<strong>25%</strong></td>
# <td>3.375000</td>
# <td><blockquote>
# <p>2.000000</p>
# </blockquote></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><strong>50%</strong></td>
# <td><blockquote>
# <p>4.000000</p>
# </blockquote></td>
# <td><blockquote>
# <p>3.000000</p>
# </blockquote></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><strong>birds</strong></td>
# <td><strong>age</strong></td>
# <td><strong>visits</strong></td>
# <td><blockquote>
# <p><strong>priority</strong></p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><strong>75%</strong></td>
# <td>5.625000</td>
# <td><blockquote>
# <p>3.750000</p>
# </blockquote></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><strong>a</strong></td>
# <td>Cranes</td>
# <td>3.5</td>
# <td>2</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>max</strong></td>
# <td><blockquote>
# <p>8.000000</p>
# </blockquote></td>
# <td><blockquote>
# <p>4.000000</p>
# </blockquote></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><strong>b</strong></td>
# <td>Cranes</td>
# <td>4.0</td>
# <td>4</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > **4. Print all the rows with only 'birds' and 'age' columns from the
# > dataframe**
# >
# > df\[\['birds','age'\]\]
#
# <table>
# <thead>
# <tr class="header">
# <th><strong>a</strong></th>
# <th><strong>birds</strong></th>
# <th><blockquote>
# <p><strong>age</strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td>Cranes</td>
# <td><blockquote>
# <p>3.5</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>b</strong></td>
# <td>Cranes</td>
# <td><blockquote>
# <p>4.0</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>c</strong></td>
# <td>plovers</td>
# <td><blockquote>
# <p>1.5</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>d</strong></td>
# <td>spoonbills</td>
# <td><blockquote>
# <p>NaN</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>e</strong></td>
# <td>spoonbills</td>
# <td><blockquote>
# <p>6.0</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>f</strong></td>
# <td>Cranes</td>
# <td><blockquote>
# <p>3.0</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>g</strong></td>
# <td>plovers</td>
# <td><blockquote>
# <p>5.5</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>h</strong></td>
# <td>Cranes</td>
# <td><blockquote>
# <p>NaN</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>i</strong></td>
# <td>spoonbills</td>
# <td><blockquote>
# <p>8.0</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>j</strong></td>
# <td>spoonbills</td>
# <td><blockquote>
# <p>4.0</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > **5. select \[2, 3, 7\] rows and in columns \['birds', 'age',
# > 'visits'\]**
# >
# > df.iloc\[\[2,3,7\]\]\[\['age','birds','visits'\]\]
#
# <table>
# <thead>
# <tr class="header">
# <th><strong>age</strong></th>
# <th><strong>birds</strong></th>
# <th><blockquote>
# <p><strong>visits</strong></p>
# </blockquote></th>
# <th>2/7</th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><strong>c</strong></td>
# <td>1.5</td>
# <td>plovers</td>
# <td><blockquote>
# <p>3</p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><strong>d</strong></td>
# <td>NaN</td>
# <td><blockquote>
# <p>spoonbills</p>
# </blockquote></td>
# <td><blockquote>
# <p>4</p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><strong>h</strong></td>
# <td>NaN</td>
# <td>Cranes</td>
# <td><blockquote>
# <p>2</p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>https://colab.research.google.com/drive/1yYBRi21r6oY0sB0G1zUdsnpVGary0Azw?authuser=2#printMode=true</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>9/25/21, 4:29 PM</p>
# </blockquote></td>
# <td>Copy of pandas_basics_practice.ipynb - Colaboratory</td>
# </tr>
# </tbody>
# </table>
#
# > **6. select the rows where the number of visits is less than 4**
# >
# > df\[df\['visits'\] \< 4\]
#
# <table>
# <thead>
# <tr class="header">
# <th><strong>a</strong></th>
# <th><strong>birds</strong></th>
# <th><strong>age</strong></th>
# <th><strong>visits</strong></th>
# <th><blockquote>
# <p><strong>priority</strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td>Cranes</td>
# <td>3.5</td>
# <td>2</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>c</strong></td>
# <td>plovers</td>
# <td>1.5</td>
# <td>3</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>e</strong></td>
# <td>spoonbills</td>
# <td>6.0</td>
# <td>3</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>g</strong></td>
# <td>plovers</td>
# <td>5.5</td>
# <td>2</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>h</strong></td>
# <td>Cranes</td>
# <td>NaN</td>
# <td>2</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>i</strong></td>
# <td>spoonbills</td>
# <td>8.0</td>
# <td>3</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>j</strong></td>
# <td>spoonbills</td>
# <td>4.0</td>
# <td>2</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > **7. select the rows with columns \['birds', 'visits'\] where the age
# > is missing i.e NaN**
# >
# > df\[df.isnull().any(axis=1)\]\[\['birds','visits'\]\]
#
# <table>
# <thead>
# <tr class="header">
# <th><strong>d</strong></th>
# <th><strong>birds</strong></th>
# <th><blockquote>
# <p><strong>visits</strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td>spoonbills</td>
# <td><blockquote>
# <p>4</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>h</strong></td>
# <td>Cranes</td>
# <td><blockquote>
# <p>2</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > **8. Select the rows where the birds is a Cranes and the age is less
# > than 4**
# >
# > df\[df\['age'\] \< 4\]\[df\['birds'\] == 'Cranes'\]
# >
# > /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1:
# > UserWarning: Boolean """Entry point for launching an IPython kernel.
#
# <table>
# <thead>
# <tr class="header">
# <th><strong>a</strong></th>
# <th><blockquote>
# <p><strong>birds</strong></p>
# </blockquote></th>
# <th><strong>age</strong></th>
# <th><strong>visits</strong></th>
# <th><blockquote>
# <p><strong>priority</strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td>Cranes</td>
# <td>3.5</td>
# <td>2</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>f</strong></td>
# <td>Cranes</td>
# <td>3.0</td>
# <td>4</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > **9. Select the rows the age is between 2 and 4(inclusive)**
# >
# > df\[df\['age'\].between(2, 4)\]
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>https://colab.research.google.com/drive/1yYBRi21r6oY0sB0G1zUdsnpVGary0Azw?authuser=2#printMode=true</p>
# </blockquote></td>
# <td>3/7</td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>9/25/21, 4:29 PM</p>
# </blockquote></th>
# <th>Copy of pandas_basics_practice.ipynb - Colaboratory</th>
# <th></th>
# <th></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><strong>birds</strong></td>
# <td><strong>age</strong></td>
# <td><strong>visits</strong></td>
# <td><blockquote>
# <p><strong>priority</strong></p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><strong>a</strong></td>
# <td>Cranes</td>
# <td>3.5</td>
# <td>2</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>b</strong></td>
# <td>Cranes</td>
# <td>4.0</td>
# <td>4</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p><strong>10. Find the total number of visits of the bird Cranes</strong> <strong>f</strong> Cranes 3.0 4 no</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><strong>j</strong></td>
# <td><blockquote>
# <p>spoonbills</p>
# </blockquote></td>
# <td>4.0</td>
# <td>2</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>df[df['birds'] == 'Cranes']['visits'].sum()</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# > 12
# >
# > **11. Calculate the mean age for each different birds in dataframe.**
# >
# > df.loc\[:,"age"\].mean()
# >
# > 4.4375
# >
# > **12. Append a new row 'k' to dataframe with your choice of values for
# > each column. Then delete**
# >
# > **that row to return the original DataFrame.**
# >
# > df.loc\['k'\] = \['parrots', 3.5, 3, 'yes'\]
# > df
#
# <table>
# <thead>
# <tr class="header">
# <th><strong>a</strong></th>
# <th><strong>birds</strong></th>
# <th><strong>age</strong></th>
# <th><strong>visits</strong></th>
# <th><blockquote>
# <p><strong>priority</strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td>Cranes</td>
# <td>3.5</td>
# <td>2</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>b</strong></td>
# <td>Cranes</td>
# <td>4.0</td>
# <td>4</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>c</strong></td>
# <td>plovers</td>
# <td>1.5</td>
# <td>3</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>d</strong></td>
# <td>spoonbills</td>
# <td>NaN</td>
# <td>4</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>e</strong></td>
# <td>spoonbills</td>
# <td>6.0</td>
# <td>3</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>f</strong></td>
# <td>Cranes</td>
# <td>3.0</td>
# <td>4</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>g</strong></td>
# <td>plovers</td>
# <td>5.5</td>
# <td>2</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>h</strong></td>
# <td>Cranes</td>
# <td>NaN</td>
# <td>2</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>i</strong></td>
# <td>spoonbills</td>
# <td>8.0</td>
# <td>3</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>j</strong></td>
# <td>spoonbills</td>
# <td>4.0</td>
# <td>2</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>k</strong></td>
# <td>parrots</td>
# <td>3.5</td>
# <td>3</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > df= df.drop('k')
# > df
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>https://colab.research.google.com/drive/1yYBRi21r6oY0sB0G1zUdsnpVGary0Azw?authuser=2#printMode=true</p>
# </blockquote></td>
# <td>4/7</td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>9/25/21, 4:29 PM</p>
# </blockquote></th>
# <th>Copy of pandas_basics_practice.ipynb - Colaboratory</th>
# <th></th>
# <th></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><strong>birds</strong></td>
# <td><strong>age</strong></td>
# <td><strong>visits</strong></td>
# <td><blockquote>
# <p><strong>priority</strong></p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><strong>a</strong></td>
# <td>Cranes</td>
# <td>3.5</td>
# <td>2</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>b</strong></td>
# <td>Cranes</td>
# <td>4.0</td>
# <td>4</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>c</strong></td>
# <td>plovers</td>
# <td>1.5</td>
# <td>3</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>d</strong></td>
# <td><blockquote>
# <p>spoonbills</p>
# </blockquote></td>
# <td><blockquote>
# <p>NaN</p>
# </blockquote></td>
# <td>4</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>e</strong></td>
# <td><blockquote>
# <p>spoonbills</p>
# </blockquote></td>
# <td>6.0</td>
# <td>3</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>f</strong></td>
# <td>Cranes</td>
# <td>3.0</td>
# <td>4</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>g</strong></td>
# <td>plovers</td>
# <td>5.5</td>
# <td>2</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>h</strong></td>
# <td>Cranes</td>
# <td><blockquote>
# <p>NaN</p>
# </blockquote></td>
# <td>2</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p><strong>i</strong> spoonbills 8.0 3 no<br />
# <strong>13. Find the number of each type of birds in dataframe (Counts)</strong></p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><strong>j</strong></td>
# <td><blockquote>
# <p>spoonbills</p>
# </blockquote></td>
# <td>4.0</td>
# <td>2</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > df\['birds'\].value_counts()
# >
# > spoonbills 4
# > Cranes 4
# > plovers 2
# > Name: birds, dtype: int64
# >
# > **14. Sort dataframe (birds) �rst by the values in the 'age' in
# > decending order, then by the value in**
# >
# > **the 'visits' column in ascending order.**
# >
# > df.sort_values(by='age', ascending=False)
#
# <table>
# <thead>
# <tr class="header">
# <th><strong>i</strong></th>
# <th><strong>birds</strong></th>
# <th><strong>age</strong></th>
# <th><strong>visits</strong></th>
# <th><blockquote>
# <p><strong>priority</strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td>spoonbills</td>
# <td>8.0</td>
# <td>3</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>e</strong></td>
# <td>spoonbills</td>
# <td>6.0</td>
# <td>3</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>g</strong></td>
# <td>plovers</td>
# <td>5.5</td>
# <td>2</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>b</strong></td>
# <td>Cranes</td>
# <td>4.0</td>
# <td>4</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>j</strong></td>
# <td>spoonbills</td>
# <td>4.0</td>
# <td>2</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>a</strong></td>
# <td>Cranes</td>
# <td>3.5</td>
# <td>2</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>f</strong></td>
# <td>Cranes</td>
# <td>3.0</td>
# <td>4</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>c</strong></td>
# <td>plovers</td>
# <td>1.5</td>
# <td>3</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>d</strong></td>
# <td>spoonbills</td>
# <td>NaN</td>
# <td>4</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>h</strong></td>
# <td>Cranes</td>
# <td>NaN</td>
# <td>2</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > df.sort_values(by='visits', ascending=True)
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>https://colab.research.google.com/drive/1yYBRi21r6oY0sB0G1zUdsnpVGary0Azw?authuser=2#printMode=true</p>
# </blockquote></td>
# <td>5/7</td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>9/25/21, 4:29 PM</p>
# </blockquote></th>
# <th><strong>birds</strong></th>
# <th><strong>age</strong></th>
# <th><strong>visits</strong></th>
# <th><blockquote>
# <p>Copy of pandas_basics_practice.ipynb - Colaboratory</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td><blockquote>
# <p><strong>priority</strong></p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>a</strong></td>
# <td>Cranes</td>
# <td>3.5</td>
# <td>2</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>g</strong></td>
# <td>plovers</td>
# <td>5.5</td>
# <td>2</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>h</strong></td>
# <td>Cranes</td>
# <td>NaN</td>
# <td>2</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>j</strong></td>
# <td>spoonbills</td>
# <td>4.0</td>
# <td>2</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>c</strong></td>
# <td>plovers</td>
# <td>1.5</td>
# <td>3</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>e</strong></td>
# <td>spoonbills</td>
# <td>6.0</td>
# <td>3</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>i</strong></td>
# <td>spoonbills</td>
# <td>8.0</td>
# <td>3</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>b</strong></td>
# <td>Cranes</td>
# <td>4.0</td>
# <td>4</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>d</strong></td>
# <td>spoonbills</td>
# <td>NaN</td>
# <td>4</td>
# <td><blockquote>
# <p>yes</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>f</strong></td>
# <td>Cranes</td>
# <td>3.0</td>
# <td>4</td>
# <td><blockquote>
# <p>no</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > **15. Replace the priority column values with'yes' should be 1 and
# > 'no' should be 0**
# >
# > \#df\[df\['priority'\].astype(int)\]
# > df\['priority'\].map({'yes':1 ,'no':0})
# >
# > a 1
# > b 1
# > c 0
# > d 1
# > e 0
# > f 0
# > g 0
# > h 1
# > i 0
# > j 0
# > Name: priority, dtype: int64
# >
# > **16. In the 'birds' column, change the 'Cranes' entries to
# > 'trumpeters'.**
# >
# > df\['birds'\].map({'Cranes':'trumpeters'})
# >
# > a trumpeters
# > b trumpeters
# > c NaN
# > d NaN
# > e NaN
# > f trumpeters
# > g NaN
# > h trumpeters
# > i NaN
# > j NaN
# > Name: birds, dtype: object
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>https://colab.research.google.com/drive/1yYBRi21r6oY0sB0G1zUdsnpVGary0Azw?authuser=2#printMode=true</p>
# </blockquote></td>
# <td>6/7</td>
# </tr>
# </tbody>
# </table>
#
# 9/25/21, 4:29 PM Copy of pandas_basics_practice.ipynb - Colaboratory
#
# <img src="attachment:vertopal_be7c34b7a3eb488f8d3f9ace22902be2/media/image1.png" style="width:7.52778in;height:0.26389in" />
#
# https://colab.research.google.com/drive/1yYBRi21r6oY0sB0G1zUdsnpVGary0Azw?authuser=2\#printMode=true
# 7/7
